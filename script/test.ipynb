# %%
import openai
import requests
import json

# %%
symbol = 'TSLA'

# %%
openai.api_key = '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'
token = 'c5cau7aad3ib55bb0h20'
url = f'https://finnhub.io/api/v1/company-news?symbol={symbol}&from=2021-09-01&to=2021-09-09&token={token}'

# %%
result = requests.get(url)
result = json.loads(result.text)
summaries = [i['summary'] for i in result]

# %%
results = {}
def get_result(query):
    if query in results:
        return results[query]
    results[query] = openai.Engine('ada').search(search_model='ada', query=query, max_rerank=5, documents=summaries[:200])
    return results[query]

# %%
def process_query(query):
    result = get_result(query)
    scores = [i['score'] for i in result['data']]
    max_idx = scores.index(max(scores))
    print(f"score: {result['data'][max_idx]['score']}")
    print(f"summary: {summaries[result['data'][max_idx]['document']]}")
    print(f"avg score: {sum(scores) / len(scores)}")

# %%
process_query("healthcare")
# Out:
# score: 338.571
# summary: U.S. stock index futures dipped on Wednesday, suggesting that the S&P 500 and Dow Jones indexes would extend losses for a third straight day, as the spread of the Delta coronavirus variant stoked worries of slowing economic growth.
# avg score: 90.24759500000008

# %%
dict(results['automobile'])
# Out:
# {'object': 'list',
#  'data': [<OpenAIObject search_result at 0x106d58680> JSON: {
#     "document": 0,
#     "object": "search_result",
#     "score": 277.38
#   },
#   <OpenAIObject search_result at 0x106d585e0> JSON: {
#     "document": 1,
#     "object": "search_result",
#     "score": -1.555
#   },
#   <OpenAIObject search_result at 0x106d58630> JSON: {
#     "document": 2,
#     "object": "search_result",
#     "score": 491.77
#   },
#   <OpenAIObject search_result at 0x106d5c6d0> JSON: {
#     "document": 3,
#     "object": "search_result",
#     "score": 326.395
#   },
#   <OpenAIObject search_result at 0x106d5cef0> JSON: {
#     "document": 4,
#     "object": "search_result",
#     "score": 50.884
#   },
#   <OpenAIObject search_result at 0x106d5ccc0> JSON: {
#     "document": 5,
#     "object": "search_result",
#     "score": 281.12
#   },
#   <OpenAIObject search_result at 0x106d5cc20> JSON: {
#     "document": 6,
#     "object": "search_result",
#     "score": 577.211
#   },
#   <OpenAIObject search_result at 0x106d5c220> JSON: {
#     "document": 7,
#     "object": "search_result",
#     "score": 387.872
#   },
#   <OpenAIObject search_result at 0x106d5c9a0> JSON: {
#     "document": 8,
#     "object": "search_result",
#     "score": 291.865
#   },
#   <OpenAIObject search_result at 0x106d5c900> JSON: {
#     "document": 9,
#     "object": "search_result",
#     "score": 321.648
#   },
#   <OpenAIObject search_result at 0x106d5cae0> JSON: {
#     "document": 10,
#     "object": "search_result",
#     "score": 312.77
#   },
#   <OpenAIObject search_result at 0x106d5c770> JSON: {
#     "document": 11,
#     "object": "search_result",
#     "score": 101.278
#   },
#   <OpenAIObject search_result at 0x106d5c630> JSON: {
#     "document": 12,
#     "object": "search_result",
#     "score": 458.544
#   },
#   <OpenAIObject search_result at 0x106def0e0> JSON: {
#     "document": 13,
#     "object": "search_result",
#     "score": 7.026
#   },
#   <OpenAIObject search_result at 0x106def2c0> JSON: {
#     "document": 14,
#     "object": "search_result",
#     "score": 521.503
#   },
#   <OpenAIObject search_result at 0x106def360> JSON: {
#     "document": 15,
#     "object": "search_result",
#     "score": 16.339
#   },
#   <OpenAIObject search_result at 0x106def400> JSON: {
#     "document": 16,
#     "object": "search_result",
#     "score": 127.915
#   },
#   <OpenAIObject search_result at 0x106def4a0> JSON: {
#     "document": 17,
#     "object": "search_result",
#     "score": 75.57
#   },
#   <OpenAIObject search_result at 0x106def540> JSON: {
#     "document": 18,
#     "object": "search_result",
#     "score": 374.997
#   },
#   <OpenAIObject search_result at 0x106def5e0> JSON: {
#     "document": 19,
#     "object": "search_result",
#     "score": 364.324
#   },
#   <OpenAIObject search_result at 0x106def680> JSON: {
#     "document": 20,
#     "object": "search_result",
#     "score": 284.161
#   },
#   <OpenAIObject search_result at 0x106def720> JSON: {
#     "document": 21,
#     "object": "search_result",
#     "score": 292.184
#   },
#   <OpenAIObject search_result at 0x106def7c0> JSON: {
#     "document": 22,
#     "object": "search_result",
#     "score": 84.61
#   },
#   <OpenAIObject search_result at 0x106def860> JSON: {
#     "document": 23,
#     "object": "search_result",
#     "score": 455.279
#   },
#   <OpenAIObject search_result at 0x106def900> JSON: {
#     "document": 24,
#     "object": "search_result",
#     "score": 355.885
#   },
#   <OpenAIObject search_result at 0x106def9a0> JSON: {
#     "document": 25,
#     "object": "search_result",
#     "score": 249.851
#   },
#   <OpenAIObject search_result at 0x106defa40> JSON: {
#     "document": 26,
#     "object": "search_result",
#     "score": 252.466
#   },
#   <OpenAIObject search_result at 0x106defae0> JSON: {
#     "document": 27,
#     "object": "search_result",
#     "score": 216.257
#   },
#   <OpenAIObject search_result at 0x106defb80> JSON: {
#     "document": 28,
#     "object": "search_result",
#     "score": 387.656
#   },
#   <OpenAIObject search_result at 0x106defc20> JSON: {
#     "document": 29,
#     "object": "search_result",
#     "score": 249.851
#   },
#   <OpenAIObject search_result at 0x106defcc0> JSON: {
#     "document": 30,
#     "object": "search_result",
#     "score": 320.913
#   },
#   <OpenAIObject search_result at 0x106defd60> JSON: {
#     "document": 31,
#     "object": "search_result",
#     "score": -1.555
#   },
#   <OpenAIObject search_result at 0x106defe00> JSON: {
#     "document": 32,
#     "object": "search_result",
#     "score": -13.443
#   },
#   <OpenAIObject search_result at 0x106defea0> JSON: {
#     "document": 33,
#     "object": "search_result",
#     "score": 23.377
#   },
#   <OpenAIObject search_result at 0x106deff40> JSON: {
#     "document": 34,
#     "object": "search_result",
#     "score": 305.293
#   },
#   <OpenAIObject search_result at 0x106d7f040> JSON: {
#     "document": 35,
#     "object": "search_result",
#     "score": 651.973
#   },
#   <OpenAIObject search_result at 0x106d7f0e0> JSON: {
#     "document": 36,
#     "object": "search_result",
#     "score": 311.652
#   },
#   <OpenAIObject search_result at 0x106d7f180> JSON: {
#     "document": 37,
#     "object": "search_result",
#     "score": -37.427
#   },
#   <OpenAIObject search_result at 0x106d7f220> JSON: {
#     "document": 38,
#     "object": "search_result",
#     "score": 164.523
#   },
#   <OpenAIObject search_result at 0x106d7f2c0> JSON: {
#     "document": 39,
#     "object": "search_result",
#     "score": 336.168
#   },
#   <OpenAIObject search_result at 0x106d7f360> JSON: {
#     "document": 40,
#     "object": "search_result",
#     "score": 18.237
#   },
#   <OpenAIObject search_result at 0x106d7f400> JSON: {
#     "document": 41,
#     "object": "search_result",
#     "score": 233.059
#   },
#   <OpenAIObject search_result at 0x106d7f4a0> JSON: {
#     "document": 42,
#     "object": "search_result",
#     "score": 140.277
#   },
#   <OpenAIObject search_result at 0x106d7f540> JSON: {
#     "document": 43,
#     "object": "search_result",
#     "score": 250.341
#   },
#   <OpenAIObject search_result at 0x106d7f5e0> JSON: {
#     "document": 44,
#     "object": "search_result",
#     "score": -0.946
#   },
#   <OpenAIObject search_result at 0x106d7f680> JSON: {
#     "document": 45,
#     "object": "search_result",
#     "score": 155.441
#   },
#   <OpenAIObject search_result at 0x106d7f720> JSON: {
#     "document": 46,
#     "object": "search_result",
#     "score": 103.88
#   },
#   <OpenAIObject search_result at 0x106d7f7c0> JSON: {
#     "document": 47,
#     "object": "search_result",
#     "score": 26.083
#   },
#   <OpenAIObject search_result at 0x106d7f860> JSON: {
#     "document": 48,
#     "object": "search_result",
#     "score": 69.81
#   },
#   <OpenAIObject search_result at 0x106d7f900> JSON: {
#     "document": 49,
#     "object": "search_result",
#     "score": 249.851
#   },
#   <OpenAIObject search_result at 0x106d7f9a0> JSON: {
#     "document": 50,
#     "object": "search_result",
#     "score": 532.033
#   },
#   <OpenAIObject search_result at 0x106d7fa40> JSON: {
#     "document": 51,
#     "object": "search_result",
#     "score": -1.555
#   },
#   <OpenAIObject search_result at 0x106d7fae0> JSON: {
#     "document": 52,
#     "object": "search_result",
#     "score": 198.903
#   },
#   <OpenAIObject search_result at 0x106d7fb80> JSON: {
#     "document": 53,
#     "object": "search_result",
#     "score": 75.648
#   },
#   <OpenAIObject search_result at 0x106d7fc20> JSON: {
#     "document": 54,
#     "object": "search_result",
#     "score": 390.27
#   },
#   <OpenAIObject search_result at 0x106d7fcc0> JSON: {
#     "document": 55,
#     "object": "search_result",
#     "score": -1.555
#   },
#   <OpenAIObject search_result at 0x106d7fd60> JSON: {
#     "document": 56,
#     "object": "search_result",
#     "score": 352.112
#   },
#   <OpenAIObject search_result at 0x106d7fe00> JSON: {
#     "document": 57,
#     "object": "search_result",
#     "score": 43.742
#   },
#   <OpenAIObject search_result at 0x106d7fea0> JSON: {
#     "document": 58,
#     "object": "search_result",
#     "score": 429.294
#   },
#   <OpenAIObject search_result at 0x106d7ff40> JSON: {
#     "document": 59,
#     "object": "search_result",
#     "score": -1.555
#   },
#   <OpenAIObject search_result at 0x106d83040> JSON: {
#     "document": 60,
#     "object": "search_result",
#     "score": 597.44
#   },
#   <OpenAIObject search_result at 0x106d830e0> JSON: {
#     "document": 61,
#     "object": "search_result",
#     "score": 249.851
#   },
#   <OpenAIObject search_result at 0x106d83180> JSON: {
#     "document": 62,
#     "object": "search_result",
#     "score": 461.766
#   },
#   <OpenAIObject search_result at 0x106d83220> JSON: {
#     "document": 63,
#     "object": "search_result",
#     "score": 340.287
#   },
#   <OpenAIObject search_result at 0x106d832c0> JSON: {
#     "document": 64,
#     "object": "search_result",
#     "score": 376.95
#   },
#   <OpenAIObject search_result at 0x106d83360> JSON: {
#     "document": 65,
#     "object": "search_result",
#     "score": 119.723
#   },
#   <OpenAIObject search_result at 0x106d83400> JSON: {
#     "document": 66,
#     "object": "search_result",
#     "score": 360.108
#   },
#   <OpenAIObject search_result at 0x106d834a0> JSON: {
#     "document": 67,
#     "object": "search_result",
#     "score": 351.656
#   },
#   <OpenAIObject search_result at 0x106d83540> JSON: {
#     "document": 68,
#     "object": "search_result",
#     "score": 337.327
#   },
#   <OpenAIObject search_result at 0x106d835e0> JSON: {
#     "document": 69,
#     "object": "search_result",
#     "score": 18.001
#   },
#   <OpenAIObject search_result at 0x106d83680> JSON: {
#     "document": 70,
#     "object": "search_result",
#     "score": 392.947
#   },
#   <OpenAIObject search_result at 0x106d83720> JSON: {
#     "document": 71,
#     "object": "search_result",
#     "score": 345.072
#   },
#   <OpenAIObject search_result at 0x106d837c0> JSON: {
#     "document": 72,
#     "object": "search_result",
#     "score": 344.239
#   },
#   <OpenAIObject search_result at 0x106d83860> JSON: {
#     "document": 73,
#     "object": "search_result",
#     "score": 335.373
#   },
#   <OpenAIObject search_result at 0x106d83900> JSON: {
#     "document": 74,
#     "object": "search_result",
#     "score": 392.533
#   },
#   <OpenAIObject search_result at 0x106d839a0> JSON: {
#     "document": 75,
#     "object": "search_result",
#     "score": 372.53
#   },
#   <OpenAIObject search_result at 0x106d83a40> JSON: {
#     "document": 76,
#     "object": "search_result",
#     "score": 309.894
#   },
#   <OpenAIObject search_result at 0x106d83ae0> JSON: {
#     "document": 77,
#     "object": "search_result",
#     "score": 237.31
#   },
#   <OpenAIObject search_result at 0x106d83b80> JSON: {
#     "document": 78,
#     "object": "search_result",
#     "score": 259.845
#   },
#   <OpenAIObject search_result at 0x106d83c20> JSON: {
#     "document": 79,
#     "object": "search_result",
#     "score": -54.912
#   },
#   <OpenAIObject search_result at 0x106d83cc0> JSON: {
#     "document": 80,
#     "object": "search_result",
#     "score": 162.131
#   },
#   <OpenAIObject search_result at 0x106d83d60> JSON: {
#     "document": 81,
#     "object": "search_result",
#     "score": 249.851
#   },
#   <OpenAIObject search_result at 0x106d83e00> JSON: {
#     "document": 82,
#     "object": "search_result",
#     "score": 262.588
#   },
#   <OpenAIObject search_result at 0x106d83ea0> JSON: {
#     "document": 83,
#     "object": "search_result",
#     "score": 140.663
#   },
#   <OpenAIObject search_result at 0x106d83f40> JSON: {
#     "document": 84,
#     "object": "search_result",
#     "score": 363.158
#   },
#   <OpenAIObject search_result at 0x106d88040> JSON: {
#     "document": 85,
#     "object": "search_result",
#     "score": 425.206
#   },
#   <OpenAIObject search_result at 0x106d880e0> JSON: {
#     "document": 86,
#     "object": "search_result",
#     "score": 376.739
#   },
#   <OpenAIObject search_result at 0x106d88180> JSON: {
#     "document": 87,
#     "object": "search_result",
#     "score": 190.906
#   },
#   <OpenAIObject search_result at 0x106d88220> JSON: {
#     "document": 88,
#     "object": "search_result",
#     "score": 156.898
#   },
#   <OpenAIObject search_result at 0x106d882c0> JSON: {
#     "document": 89,
#     "object": "search_result",
#     "score": 217.539
#   },
#   <OpenAIObject search_result at 0x106d88360> JSON: {
#     "document": 90,
#     "object": "search_result",
#     "score": 386.39
#   },
#   <OpenAIObject search_result at 0x106d88400> JSON: {
#     "document": 91,
#     "object": "search_result",
#     "score": 406.178
#   },
#   <OpenAIObject search_result at 0x106d884a0> JSON: {
#     "document": 92,
#     "object": "search_result",
#     "score": 223.915
#   },
#   <OpenAIObject search_result at 0x106d88540> JSON: {
#     "document": 93,
#     "object": "search_result",
#     "score": 520.506
#   },
#   <OpenAIObject search_result at 0x106d885e0> JSON: {
#     "document": 94,
#     "object": "search_result",
#     "score": 577.106
#   },
#   <OpenAIObject search_result at 0x106d88680> JSON: {
#     "document": 95,
#     "object": "search_result",
#     "score": 210.382
#   },
#   <OpenAIObject search_result at 0x106d88720> JSON: {
#     "document": 96,
#     "object": "search_result",
#     "score": 493.445
#   },
#   <OpenAIObject search_result at 0x106d887c0> JSON: {
#     "document": 97,
#     "object": "search_result",
#     "score": 249.851
#   },
#   <OpenAIObject search_result at 0x106d88860> JSON: {
#     "document": 98,
#     "object": "search_result",
#     "score": 531.716
#   },
#   <OpenAIObject search_result at 0x106d88900> JSON: {
#     "document": 99,
#     "object": "search_result",
#     "score": 103.721
#   },
#   <OpenAIObject search_result at 0x106d889a0> JSON: {
#     "document": 100,
#     "object": "search_result",
#     "score": -33.387
#   },
#   <OpenAIObject search_result at 0x106d88a40> JSON: {
#     "document": 101,
#     "object": "search_result",
#     "score": 249.851
#   },
#   <OpenAIObject search_result at 0x106d88ae0> JSON: {
#     "document": 102,
#     "object": "search_result",
#     "score": 322.907
#   },
#   <OpenAIObject search_result at 0x106d88b80> JSON: {
#     "document": 103,
#     "object": "search_result",
#     "score": 425.877
#   },
#   <OpenAIObject search_result at 0x106d88c20> JSON: {
#     "document": 104,
#     "object": "search_result",
#     "score": 498.36
#   },
#   <OpenAIObject search_result at 0x106d88cc0> JSON: {
#     "document": 105,
#     "object": "search_result",
#     "score": 7.412
#   },
#   <OpenAIObject search_result at 0x106d88d60> JSON: {
#     "document": 106,
#     "object": "search_result",
#     "score": 99.933
#   },
#   <OpenAIObject search_result at 0x106d88e00> JSON: {
#     "document": 107,
#     "object": "search_result",
#     "score": 24.761
#   },
#   <OpenAIObject search_result at 0x106d88ea0> JSON: {
#     "document": 108,
#     "object": "search_result",
#     "score": 518.422
#   },
#   <OpenAIObject search_result at 0x106d88f40> JSON: {
#     "document": 109,
#     "object": "search_result",
#     "score": 74.426
#   },
#   <OpenAIObject search_result at 0x106d8c040> JSON: {
#     "document": 110,
#     "object": "search_result",
#     "score": 463.476
#   },
#   <OpenAIObject search_result at 0x106d8c0e0> JSON: {
#     "document": 111,
#     "object": "search_result",
#     "score": 60.892
#   },
#   <OpenAIObject search_result at 0x106d8c180> JSON: {
#     "document": 112,
#     "object": "search_result",
#     "score": 162.131
#   },
#   <OpenAIObject search_result at 0x106d8c220> JSON: {
#     "document": 113,
#     "object": "search_result",
#     "score": -1.555
#   },
#   <OpenAIObject search_result at 0x106d8c2c0> JSON: {
#     "document": 114,
#     "object": "search_result",
#     "score": 131.05
#   },
#   <OpenAIObject search_result at 0x106d8c360> JSON: {
#     "document": 115,
#     "object": "search_result",
#     "score": -1.555
#   },
#   <OpenAIObject search_result at 0x106d8c400> JSON: {
#     "document": 116,
#     "object": "search_result",
#     "score": 89.758
#   },
#   <OpenAIObject search_result at 0x106d8c4a0> JSON: {
#     "document": 117,
#     "object": "search_result",
#     "score": 75.491
#   },
#   <OpenAIObject search_result at 0x106d8c540> JSON: {
#     "document": 118,
#     "object": "search_result",
#     "score": 57.075
#   },
#   <OpenAIObject search_result at 0x106d8c5e0> JSON: {
#     "document": 119,
#     "object": "search_result",
#     "score": 141.321
#   },
#   <OpenAIObject search_result at 0x106d8c680> JSON: {
#     "document": 120,
#     "object": "search_result",
#     "score": 277.896
#   },
#   <OpenAIObject search_result at 0x106d8c720> JSON: {
#     "document": 121,
#     "object": "search_result",
#     "score": 35.556
#   },
#   <OpenAIObject search_result at 0x106d8c7c0> JSON: {
#     "document": 122,
#     "object": "search_result",
#     "score": -1.555
#   },
#   <OpenAIObject search_result at 0x106d8c860> JSON: {
#     "document": 123,
#     "object": "search_result",
#     "score": 162.131
#   },
#   <OpenAIObject search_result at 0x106d8c900> JSON: {
#     "document": 124,
#     "object": "search_result",
#     "score": 518.422
#   },
#   <OpenAIObject search_result at 0x106d8c9a0> JSON: {
#     "document": 125,
#     "object": "search_result",
#     "score": 246.385
#   },
#   <OpenAIObject search_result at 0x106d8ca40> JSON: {
#     "document": 126,
#     "object": "search_result",
#     "score": 358.575
#   },
#   <OpenAIObject search_result at 0x106d8cae0> JSON: {
#     "document": 127,
#     "object": "search_result",
#     "score": 38.287
#   },
#   <OpenAIObject search_result at 0x106d8cb80> JSON: {
#     "document": 128,
#     "object": "search_result",
#     "score": -24.439
#   },
#   <OpenAIObject search_result at 0x106d8cc20> JSON: {
#     "document": 129,
#     "object": "search_result",
#     "score": -14.178
#   },
#   <OpenAIObject search_result at 0x106d8ccc0> JSON: {
#     "document": 130,
#     "object": "search_result",
#     "score": 644.366
#   },
#   <OpenAIObject search_result at 0x106d8cd60> JSON: {
#     "document": 131,
#     "object": "search_result",
#     "score": 149.052
#   },
#   <OpenAIObject search_result at 0x106d8ce00> JSON: {
#     "document": 132,
#     "object": "search_result",
#     "score": 243.915
#   },
#   <OpenAIObject search_result at 0x106d8cea0> JSON: {
#     "document": 133,
#     "object": "search_result",
#     "score": 386.245
#   },
#   <OpenAIObject search_result at 0x106d8cf40> JSON: {
#     "document": 134,
#     "object": "search_result",
#     "score": 511.799
#   },
#   <OpenAIObject search_result at 0x106d90040> JSON: {
#     "document": 135,
#     "object": "search_result",
#     "score": 438.342
#   },
#   <OpenAIObject search_result at 0x106d900e0> JSON: {
#     "document": 136,
#     "object": "search_result",
#     "score": 399.019
#   },
#   <OpenAIObject search_result at 0x106d90180> JSON: {
#     "document": 137,
#     "object": "search_result",
#     "score": 315.355
#   },
#   <OpenAIObject search_result at 0x106d90220> JSON: {
#     "document": 138,
#     "object": "search_result",
#     "score": 418.058
#   },
#   <OpenAIObject search_result at 0x106d902c0> JSON: {
#     "document": 139,
#     "object": "search_result",
#     "score": 232.425
#   },
#   <OpenAIObject search_result at 0x106d90360> JSON: {
#     "document": 140,
#     "object": "search_result",
#     "score": 363.202
#   },
#   <OpenAIObject search_result at 0x106d90400> JSON: {
#     "document": 141,
#     "object": "search_result",
#     "score": 477.871
#   },
#   <OpenAIObject search_result at 0x106d904a0> JSON: {
#     "document": 142,
#     "object": "search_result",
#     "score": 335.886
#   },
#   <OpenAIObject search_result at 0x106d90540> JSON: {
#     "document": 143,
#     "object": "search_result",
#     "score": 158.383
#   },
#   <OpenAIObject search_result at 0x106d905e0> JSON: {
#     "document": 144,
#     "object": "search_result",
#     "score": 189.242
#   },
#   <OpenAIObject search_result at 0x106d90680> JSON: {
#     "document": 145,
#     "object": "search_result",
#     "score": 353.658
#   },
#   <OpenAIObject search_result at 0x106d90720> JSON: {
#     "document": 146,
#     "object": "search_result",
#     "score": 340.977
#   },
#   <OpenAIObject search_result at 0x106d907c0> JSON: {
#     "document": 147,
#     "object": "search_result",
#     "score": 436.395
#   },
#   <OpenAIObject search_result at 0x106d90860> JSON: {
#     "document": 148,
#     "object": "search_result",
#     "score": 364.384
#   },
#   <OpenAIObject search_result at 0x106d90900> JSON: {
#     "document": 149,
#     "object": "search_result",
#     "score": 407.946
#   },
#   <OpenAIObject search_result at 0x106d909a0> JSON: {
#     "document": 150,
#     "object": "search_result",
#     "score": 334.977
#   },
#   <OpenAIObject search_result at 0x106d90a40> JSON: {
#     "document": 151,
#     "object": "search_result",
#     "score": 44.52
#   },
#   <OpenAIObject search_result at 0x106d90ae0> JSON: {
#     "document": 152,
#     "object": "search_result",
#     "score": 93.848
#   },
#   <OpenAIObject search_result at 0x106d90b80> JSON: {
#     "document": 153,
#     "object": "search_result",
#     "score": 118.389
#   },
#   <OpenAIObject search_result at 0x106d90c20> JSON: {
#     "document": 154,
#     "object": "search_result",
#     "score": 443.909
#   },
#   <OpenAIObject search_result at 0x106d90cc0> JSON: {
#     "document": 155,
#     "object": "search_result",
#     "score": 419.777
#   },
#   <OpenAIObject search_result at 0x106d90d60> JSON: {
#     "document": 156,
#     "object": "search_result",
#     "score": 419.872
#   },
#   <OpenAIObject search_result at 0x106d90e00> JSON: {
#     "document": 157,
#     "object": "search_result",
#     "score": -16.151
#   },
#   <OpenAIObject search_result at 0x106d90ea0> JSON: {
#     "document": 158,
#     "object": "search_result",
#     "score": 406.279
#   },
#   <OpenAIObject search_result at 0x106d90f40> JSON: {
#     "document": 159,
#     "object": "search_result",
#     "score": 403.443
#   },
#   <OpenAIObject search_result at 0x106d95040> JSON: {
#     "document": 160,
#     "object": "search_result",
#     "score": 332.935
#   },
#   <OpenAIObject search_result at 0x106d950e0> JSON: {
#     "document": 161,
#     "object": "search_result",
#     "score": 386.942
#   },
#   <OpenAIObject search_result at 0x106d95180> JSON: {
#     "document": 162,
#     "object": "search_result",
#     "score": 360.585
#   },
#   <OpenAIObject search_result at 0x106d95220> JSON: {
#     "document": 163,
#     "object": "search_result",
#     "score": 492.525
#   },
#   <OpenAIObject search_result at 0x106d952c0> JSON: {
#     "document": 164,
#     "object": "search_result",
#     "score": 114.943
#   },
#   <OpenAIObject search_result at 0x106d95360> JSON: {
#     "document": 165,
#     "object": "search_result",
#     "score": 339.227
#   },
#   <OpenAIObject search_result at 0x106d95400> JSON: {
#     "document": 166,
#     "object": "search_result",
#     "score": 520.935
#   },
#   <OpenAIObject search_result at 0x106d954a0> JSON: {
#     "document": 167,
#     "object": "search_result",
#     "score": 456.333
#   },
#   <OpenAIObject search_result at 0x106d95540> JSON: {
#     "document": 168,
#     "object": "search_result",
#     "score": 334.977
#   },
#   <OpenAIObject search_result at 0x106d955e0> JSON: {
#     "document": 169,
#     "object": "search_result",
#     "score": 249.851
#   },
#   <OpenAIObject search_result at 0x106d95680> JSON: {
#     "document": 170,
#     "object": "search_result",
#     "score": 397.831
#   },
#   <OpenAIObject search_result at 0x106d95720> JSON: {
#     "document": 171,
#     "object": "search_result",
#     "score": 24.42
#   },
#   <OpenAIObject search_result at 0x106d957c0> JSON: {
#     "document": 172,
#     "object": "search_result",
#     "score": 353.196
#   },
#   <OpenAIObject search_result at 0x106d95860> JSON: {
#     "document": 173,
#     "object": "search_result",
#     "score": 367.861
#   },
#   <OpenAIObject search_result at 0x106d95900> JSON: {
#     "document": 174,
#     "object": "search_result",
#     "score": -37.922
#   },
#   <OpenAIObject search_result at 0x106d959a0> JSON: {
#     "document": 175,
#     "object": "search_result",
#     "score": 493.901
#   },
#   <OpenAIObject search_result at 0x106d95a40> JSON: {
#     "document": 176,
#     "object": "search_result",
#     "score": 462.769
#   },
#   <OpenAIObject search_result at 0x106d95ae0> JSON: {
#     "document": 177,
#     "object": "search_result",
#     "score": 391.386
#   },
#   <OpenAIObject search_result at 0x106d95b80> JSON: {
#     "document": 178,
#     "object": "search_result",
#     "score": 581.022
#   },
#   <OpenAIObject search_result at 0x106d95c20> JSON: {
#     "document": 179,
#     "object": "search_result",
#     "score": 129.453
#   },
#   <OpenAIObject search_result at 0x106d95cc0> JSON: {
#     "document": 180,
#     "object": "search_result",
#     "score": 525.087
#   },
#   <OpenAIObject search_result at 0x106d95d60> JSON: {
#     "document": 181,
#     "object": "search_result",
#     "score": 144.389
#   },
#   <OpenAIObject search_result at 0x106d95e00> JSON: {
#     "document": 182,
#     "object": "search_result",
#     "score": 536.469
#   },
#   <OpenAIObject search_result at 0x106d95ea0> JSON: {
#     "document": 183,
#     "object": "search_result",
#     "score": 474.538
#   },
#   <OpenAIObject search_result at 0x106d95f40> JSON: {
#     "document": 184,
#     "object": "search_result",
#     "score": 112.287
#   },
#   <OpenAIObject search_result at 0x106d99040> JSON: {
#     "document": 185,
#     "object": "search_result",
#     "score": 444.796
#   },
#   <OpenAIObject search_result at 0x106d990e0> JSON: {
#     "document": 186,
#     "object": "search_result",
#     "score": 249.851
#   },
#   <OpenAIObject search_result at 0x106d99180> JSON: {
#     "document": 187,
#     "object": "search_result",
#     "score": 73.51
#   },
#   <OpenAIObject search_result at 0x106d99220> JSON: {
#     "document": 188,
#     "object": "search_result",
#     "score": 195.432
#   },
#   <OpenAIObject search_result at 0x106d992c0> JSON: {
#     "document": 189,
#     "object": "search_result",
#     "score": -1.555
#   },
#   <OpenAIObject search_result at 0x106d99360> JSON: {
#     "document": 190,
#     "object": "search_result",
#     "score": 544.94
#   },
#   <OpenAIObject search_result at 0x106d99400> JSON: {
#     "document": 191,
#     "object": "search_result",
#     "score": 190.906
#   },
#   <OpenAIObject search_result at 0x106d994a0> JSON: {
#     "document": 192,
#     "object": "search_result",
#     "score": 377.064
#   },
#   <OpenAIObject search_result at 0x106d99540> JSON: {
#     "document": 193,
#     "object": "search_result",
#     "score": 443.183
#   },
#   <OpenAIObject search_result at 0x106d995e0> JSON: {
#     "document": 194,
#     "object": "search_result",
#     "score": 529.421
#   },
#   <OpenAIObject search_result at 0x106d99680> JSON: {
#     "document": 195,
#     "object": "search_result",
#     "score": 190.906
#   },
#   <OpenAIObject search_result at 0x106d99720> JSON: {
#     "document": 196,
#     "object": "search_result",
#     "score": 405.549
#   },
#   <OpenAIObject search_result at 0x106d997c0> JSON: {
#     "document": 197,
#     "object": "search_result",
#     "score": 219.411
#   },
#   <OpenAIObject search_result at 0x106d99860> JSON: {
#     "document": 198,
#     "object": "search_result",
#     "score": 307.371
#   },
#   <OpenAIObject search_result at 0x106d99900> JSON: {
#     "document": 199,
#     "object": "search_result",
#     "score": 204.134
#   }],
#  'model': 'ada:2020-05-03'}
